Remington 9 1/2 M	ELDX175	3.32	N560	59.5	5	7/5/25	2675	18.5	6.8	1.13	54	2
Remington 9 1/2 M	ELDX175	3.32	N560	60.0	5	7/5/25	2690	11.4	4.2	1.80	55	3
Remington 9 1/2 M	ELDX175	3.32	H4831	57.5	5	7/5/25	2576	20.8	7.0	0.70	56	4
Remington 9 1/2 M	ELDX175	3.32	H4831	58.0	5	7/5/25	2601	23.4	8.6	1.40	57	5
Remington 9 1/2 M	ELDX175	3.32	H4831	58.5	5	7/5/25	2618	34.7	11.4	1.50	58	6
Remington 9 1/2 M	ELDX175	3.40	H1000	65.0	5	7/14/25	2793	49.7	17.3	1.13	59	1
Remington 9 1/2 M	ELDX175	3.40	H1000	65.5	5	7/14/25	2817	36.3	14.4	2.00	60	2
Remington 9 1/2 M	ELDX175	3.40	H1000	66.0	5	7/14/25	2848	20.8	6.8	1.70	61	3
Remington 9 1/2 M	ELDX175	3.40	H1000	66.5	5	7/14/25	2864	18.0	6.4	2.20	62	4
Remington 9 1/2 M	ELDX175	3.40	H1000	67.0	5	7/14/25	2894	30.8	11.6	2.20	63	5
Remington 9 1/2 M	ELDX175	3.40	H4831	58.0	5	7/14/25	2621	43.5	15.7	1.90	64	6
Remington 9 1/2 M	ELDX175	3.40	H4831	59.0	5	7/14/25	2664	16.0	5.2	1.15	65	7
Remington 9 1/2 M	ELDX175	3.40	H4831	60.0	5	7/14/25	2710	30.7	12.6	1.90	66	8
Remington 9 1/2 M	ELDX175	3.40	H4831	61.0	5	7/14/25	2742	12.8	5.3	1.40	67	9
Remington 9 1/2 M	ELDX175	3.40	H4831	62.0	5	7/14/25	2786	15.5	5.1	1.50	68	10"""

df = pd.read_csv(StringIO(data_text), sep='\t')

# Clean up data types
df['FPS Avg'] = pd.to_numeric(df['FPS Avg'], errors='coerce')
df['FPS SD'] = pd.to_numeric(df['FPS SD'], errors='coerce')
df['Group Size'] = pd.to_numeric(df['Group Size'], errors='coerce')
df['Weight'] = pd.to_numeric(df['Weight'], errors='coerce')
# Out:
# c:\Users\ken\AppData\Local\Programs\Python\Python313\python.exe

# %%
# Show which loads had smallest group size
top_groups = df.sort_values('Group Size').head(10)[['Powder', 'Weight', 'COL', 'FPS Avg', 'FPS SD', 'Group Size']]
print("Top 10 Smallest Groups")
display(top_groups)  # or just top_groups
# Out:
# Top 10 Smallest Groups
#    Powder  Weight   COL  FPS Avg  FPS SD  Group Size
# 26   RL23    59.5  3.32   2736.0    13.1        0.60
# 50  H4831    58.0  3.32   2598.0     6.6        0.70
# 55  H4831    57.5  3.32   2576.0     7.0        0.70
# 37   N560    60.0  3.32   2689.0     5.7        0.75
# 40  H4831    58.0  3.32   2598.0     5.2        0.80
# 46   N560    59.0  3.32   2654.0    14.9        0.85
# 29   RL23    61.0  3.32   2802.0     4.4        0.90
# 28   RL23    60.5  3.32   2778.0     9.9        1.00
# 48  H4831    56.0  3.32   2527.0     8.3        1.10
# 53   N560    59.5  3.32   2675.0     6.8        1.13

# %%
# Average group size by powder and weight, with count, top 10 only
powder_weight_stats = (
    df.groupby(['Powder', 'Weight'])
    .agg(
        mean_group_size=('Group Size', 'mean'),
        mean_fps=('FPS Avg', 'mean'),
        count=('Group Size', 'count')
    )
    .reset_index()
    .sort_values('mean_group_size')
    .head(10)
)

print("Top 10 Powder/Weight Combinations by Average Group Size (with mean FPS and count):")
display(powder_weight_stats)
# Out:
# Top 10 Powder/Weight Combinations by Average Group Size (with mean FPS and count):
#    Powder  Weight  mean_group_size     mean_fps  count
# 7   H4831    57.5         0.700000  2576.000000      1
# 27   RL23    61.0         1.050000  2793.000000      2
# 5   H4831    56.0         1.100000  2527.000000      1
# 26   RL23    60.5         1.125000  2775.500000      2
# 18   N560    59.5         1.130000  2675.000000      1
# 8   H4831    58.0         1.200000  2604.500000      4
# 0   H1000    65.0         1.210000  2786.333333      3
# 21   N560    62.0         1.250000  2770.000000      1
# 24   RL23    59.5         1.256667  2731.666667      3
# 10  H4831    59.0         1.260000  2657.500000      2

# %%
# Compute correlation with Group Size
corr_columns = ['FPS Avg', 'FPS ES', 'FPS SD', 'Group', 'Day Group', 'Group Size']
corr_df = df[corr_columns].corr()

print("Correlation Matrix (Group Size and related columns):")
display(corr_df['Group Size'].sort_values(ascending=False))  # Shows correlation with Group Size
# Out:
# Correlation Matrix (Group Size and related columns):
# Group Size    1.000000
# FPS Avg       0.423863
# FPS SD        0.263288
# FPS ES        0.237113
# Day Group     0.013551
# Group        -0.327411
# Name: Group Size, dtype: float64

# %%
# Basic stats
group_stats = df.groupby('Powder')[['FPS Avg', 'FPS ES', 'FPS SD', 'Group Size']].agg(['mean', 'count']).dropna()

# Sort by mean group size (ascending)
group_stats = group_stats.sort_values(('Group Size', 'mean'))

print("Powder Performance Summary (sorted by mean group size)")
display(group_stats)
# Out:
# Powder Performance Summary (sorted by mean group size)
#              FPS Avg           FPS ES           FPS SD       Group Size
#                 mean count       mean count       mean count       mean count
# Powder
# RL23     2755.000000    11  18.063636    11   6.927273    11   1.233636    11
# H4831    2646.066667    15  23.840000    15   8.880000    15   1.312000    15
# N560     2713.250000     8  21.237500     8   7.512500     8   1.322500     8
# H1000    2839.272727    11  34.600000    11  13.363636    11   1.630000    11
# Retumbo  2730.666667     3  22.500000     3   8.566667     3   1.650000     3
# ELDX     2879.000000     2  36.500000     2  18.500000     2   2.050000     5
# IMR7828  2811.000000     3  23.000000     3   8.666667     3   2.133333     3
